# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

X, y = make_classification(n_samples=200, n_features=2, n_redundant=0, class_sep=2)

km = KMeans(n_clusters=4)
km.fit(X)
y_pred = km.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_pred)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.savefig('kmeans0.png')

# %%
from sklearn.cluster import KMeans

# %%
plt.savefig('kmeans1.png')

# %%
centers = km.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.scatter(centers[:, 0], centers[:, 1], s=100, color='red')
plt.savefig('kmeans2.png')

# %%
km = KMeans(n_clusters=8)
km.fit(X)
y_pred = km.predict(X)
centers = km.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.scatter(centers[:, 0], centers[:, 1], s=100, color='red')
plt.savefig('kmeans_over.png')

# %%
km = KMeans(n_clusters=2)
km.fit(X)
y_pred = km.predict(X)
centers = km.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.scatter(centers[:, 0], centers[:, 1], s=100, color='red')
plt.savefig('kmeans_under.png')
